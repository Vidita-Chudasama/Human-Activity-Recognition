# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd /content/drive/My\ Drive/6th\ SEM/MP-3/HAR/human-activity-recognition
# Out:
# /content/drive/My Drive/6th SEM/MP-3/HAR/human-activity-recognition

# %%
# !python human_activity_reco.py --model resnet-34_kinetics.onnx --classes action_recognition_kinetics.txt --input Input/Inp_17.mp4 --output Output/Out_17.avi --codec MJPG
# Out:
# [INFO] loading human activity recognition model...
# [INFO] accessing video stream...
# [INFO] no frame read from stream - exiting
# [INFO] cleaning up...
# [INFO] See the output video

# %%
# !python human_activity_reco_deque.py --model resnet-34_kinetics.onnx \
    --classes action_recognition_kinetics.txt \
    --input Input/Inp_6.mp4 \
    --output Output_deque/Out_6.avi \
    --codec MJPG
# Out:
# [INFO] loading human activity recognition model...
# [INFO] accessing video stream...
# [INFO] no frame read from stream - exiting
# [INFO] cleaning up...
# [INFO] See the output video
